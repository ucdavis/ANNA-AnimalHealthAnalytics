# %%
# Import necessary libraries

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from copy import deepcopy
from skopt import BayesSearchCV
import time
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score
import pickle
from imblearn.over_sampling import SMOTE
from sklearn.impute import KNNImputer

# %% [markdown]
# ## PSS MLM

# %%
# Load the processed training dataset

train = pd.read_csv( "../data/processed/pss_train.csv",  index_col=0)

# Split the dataset into features (X) and target variable (y)
y_train_original = train['Is_shunt']
X_train_original = train.drop(['Is_shunt'], axis=1)



# define KNN imputer
imputer = KNNImputer()
# fit on the X_train
imputer.fit(X_train_original)
# transform the X_train
X_train_scaled = imputer.transform(X_train_original)

# Split the unscaled data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_original, y_train_original, test_size=0.10, shuffle=True, random_state= 123)

# Split the scaled data into training and validation sets
X_train_scaled, X_val_scaled, y_train_scaled, y_val_scaled = train_test_split(X_train_scaled, y_train_original, test_size=0.10, shuffle=True, random_state= 123)

# %% [markdown]
# ## Hyperparameter tuning and training
#
# This code optimizes an XGBoost Classifier using 10-fold Bayesian search, seeking the best combination of hyperparameters for optimal performance. The model is trained and evaluated using accuracy (ACC), F1 score, and ROC AUC.
#
# ### Bayesian search:
#
# Unlike random or grid search methods, Bayesian optimization keeps track of past evaluation results to construct a probabilistic model that maps hyperparameters to the probability of achieving a certain score on the objective function. In other words, it offers a more thorough exploration of the hyperparameter space compared to random search, and it is faster than grid search while being less likely to overfit.
#
#
# $ arg \, min_{θ} (E[objective(θ)∣data])$

# %% [markdown]
# ### XGBoost Model Training with Unscaled Data

# %%
# Initializing XGBoost Classifier with default parameters


xgbc = XGBClassifier(objective='binary:logistic',
                          booster='gbtree',
                          eval_metric='auc',
                          tree_method='hist',
                          grow_policy='lossguide')

# Training the XGBoost Classifier

xgbc.fit(X_train , y_train.values.ravel())

# Defining default parameters and the parameter grid for Bayesian search

default_params = {}
gparams = xgbc.get_params()

for key in gparams.keys():
    gp = gparams[key]
    default_params[key] = [gp]

# Deep copy the default parameters for potential modifications
params = deepcopy(default_params)

# Define the hyperparameter grid for hyperparameter tuning

param_grid = {'gamma': [2**i for i in range(-2, 8)],
              'learning_rate': [0.01,0.02, 0.025, 0.03, 0.04, 0.05, 0.06, 0.7,0.08],
              'max_depth': [2,5,6,7,8,9,10],
              'n_estimators': [50,65,80,100,115,130,150],
              'reg_alpha': [2**i for i in range(-2, 8)],
              'reg_lambda': [2**i for i in range(-2, 8)]}

# %%
# %%time

#start time
t0 = time.time()

#No. of jobs
bcvj = int(np.cumsum([len(x) for x in param_grid.values()])[-1])


# Initializing XGBoost Classifier with default parameters before Bayesian search
default_params_xgb = {}

for key in default_params.keys():
    default_params_xgb[key] = default_params[key][0]

#providing default parameters to xgbc model, before bayesian search cross-validation
xgbc = XGBClassifier(**default_params_xgb)


# Initializing Bayesian SearchCV with XGBoost Classifier
clf = BayesSearchCV(estimator=xgbc, search_spaces=param_grid, n_iter=bcvj, scoring='accuracy', cv=10, return_train_score=True, verbose=3)
clf.fit(X_train, y_train.values.ravel())

# Storing results in a DataFrame
df = pd.DataFrame(clf.cv_results_)
    
# Generating predictions for train and validation sets
train_predictions = clf.predict(X_train)
val_predictions = clf.predict(X_val)
    
# Calculating confusion matrices
cfm_train = confusion_matrix(y_train, train_predictions)
cfm_val = confusion_matrix(y_val, val_predictions)
    
# Calculating accuracy scores
accs_train = accuracy_score(y_train, train_predictions)
accs_val = accuracy_score(y_val, val_predictions)

    
# Calculating F1 scores
f1s_train_p1 = f1_score(y_train, train_predictions, pos_label=1)
f1s_train_p0 = f1_score(y_train, train_predictions, pos_label=0)
f1s_val_p1 = f1_score(y_val, val_predictions, pos_label=1)
f1s_val_p0 = f1_score(y_val, val_predictions, pos_label=0)

    
# Calculating Area Under the Receiver Operating Characteristic Curve
val_ras = roc_auc_score(y_val, clf.predict_proba(X_val)[:,1])
    
#best parameters
bp = clf.best_params_
results_dict = {}
    
# Storing computed values in a results dictionary
results_dict['xgbc_bcv'] = {'classifier': deepcopy(clf),
                            'cv_results': df.copy(),
                            'cfm_train': cfm_train,
                            'cfm_test': cfm_val,
                            'train_accuracy': accs_train,
                            'val_accuracy': accs_val,
                            'train F1-score label 1': f1s_train_p1,
                            'train F1-score label 0': f1s_train_p0,
                            'val F1-score label 1': f1s_val_p1,
                            'val F1-score label 0': f1s_val_p0,
                            'val roc auc score': val_ras,
                            'best_params': bp}

#stop time
t1 = time.time()

# Calculating elapsed time
bcvt = t1 - t0
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.920, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.927, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.925, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.929, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.913, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.913, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.916, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.932, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.927, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.2, reg_lambda=102.4;, score=(train=0.920, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.962) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.885) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.885) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.846) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.949) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.962) total time=   0.1s
# [CV 7/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.923) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.897) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=1.000, test=0.872) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.03, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.4;, score=(train=0.999, test=0.910) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.976, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.979, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.976, test=0.949) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.982, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.980, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.976, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.980, test=0.923) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.977, test=0.897) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.977, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.04, max_depth=5, n_estimators=130, reg_alpha=0.4, reg_lambda=25.6;, score=(train=0.979, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.999, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.997, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=1.000, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.996, test=0.846) total time=   0.0s
# [CV 5/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.999, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.999, test=0.949) total time=   0.0s
# [CV 7/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.999, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.996, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.999, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.0, learning_rate=0.04, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=1.6;, score=(train=0.997, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.838, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.848, test=0.833) total time=   0.0s
# [CV 3/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.845, test=0.821) total time=   0.0s
# [CV 4/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.844, test=0.756) total time=   0.0s
# [CV 5/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.842, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 7/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.845, test=0.846) total time=   0.0s
# [CV 8/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.844, test=0.808) total time=   0.0s
# [CV 9/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=102.4, learning_rate=0.02, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.0;, score=(train=0.838, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.875, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.873, test=0.795) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.885, test=0.821) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.890, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.873, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.883, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.858, test=0.821) total time=   0.0s
# [CV 8/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.886, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.883, test=0.833) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.879, test=0.846) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.960, test=0.937) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.970, test=0.833) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.959, test=0.846) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.963, test=0.821) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.963, test=0.910) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.960, test=0.885) total time=   0.1s
# [CV 7/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.960, test=0.897) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.962, test=0.885) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.957, test=0.859) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.967, test=0.885) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.949, test=0.975) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.954, test=0.923) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.957, test=0.885) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.953, test=0.885) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.950, test=0.974) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.952, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.954, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.950, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.953, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=0.06, max_depth=2, n_estimators=100, reg_alpha=3.2, reg_lambda=1.6;, score=(train=0.956, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.872, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.871, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.879, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.876, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.878, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.851, test=0.821) total time=   0.0s
# [CV 7/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.875, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.882, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.872, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=25.6, learning_rate=0.01, max_depth=5, n_estimators=100, reg_alpha=6.4, reg_lambda=0.2;, score=(train=0.872, test=0.846) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.477, test=0.481) total time=   0.0s
# [CV 2/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 3/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 4/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 5/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 6/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 7/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 8/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 9/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 10/10] END gamma=0.0, learning_rate=0.01, max_depth=8, n_estimators=100, reg_alpha=200.0, reg_lambda=25.6;, score=(train=0.478, test=0.474) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.915, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.923, test=0.859) total time=   0.0s
# [CV 3/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.932, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.927, test=0.833) total time=   0.0s
# [CV 5/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.926, test=0.923) total time=   0.0s
# [CV 6/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.919, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.920, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.925, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.920, test=0.846) total time=   0.0s
# [CV 10/10] END gamma=12.8, learning_rate=0.02, max_depth=8, n_estimators=65, reg_alpha=0.4, reg_lambda=0.1;, score=(train=0.920, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.902, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.912, test=0.821) total time=   0.0s
# [CV 3/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.919, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.906, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.909, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.882, test=0.872) total time=   0.0s
# [CV 7/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.908, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.917, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.906, test=0.833) total time=   0.0s
# [CV 10/10] END gamma=0.0, learning_rate=0.03, max_depth=8, n_estimators=100, reg_alpha=51.2, reg_lambda=102.4;, score=(train=0.910, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.477, test=0.481) total time=   0.0s
# [CV 2/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 3/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 4/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 5/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 6/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 7/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 8/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 9/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 10/10] END gamma=1.6, learning_rate=0.04, max_depth=5, n_estimators=115, reg_alpha=200.0, reg_lambda=102.4;, score=(train=0.478, test=0.474) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.870, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.875, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.886, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.885, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.875, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.866, test=0.846) total time=   0.0s
# [CV 7/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.878, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.879, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.871, test=0.808) total time=   0.0s
# [CV 10/10] END gamma=25.6, learning_rate=0.06, max_depth=8, n_estimators=65, reg_alpha=12.8, reg_lambda=1.6;, score=(train=0.878, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.934, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.936, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.936, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.937, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.935, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.933, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.935, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.940, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.937, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=3.2, learning_rate=0.02, max_depth=7, n_estimators=80, reg_alpha=3.2, reg_lambda=6.4;, score=(train=0.937, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.953, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.956, test=0.859) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.957, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.956, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.954, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.949, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.959, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.954, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.959, test=0.910) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.04, max_depth=6, n_estimators=130, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.957, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.823, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.835, test=0.833) total time=   0.0s
# [CV 3/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.835, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.844, test=0.756) total time=   0.0s
# [CV 5/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.828, test=0.897) total time=   0.0s
# [CV 6/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 7/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.832, test=0.821) total time=   0.0s
# [CV 8/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.836, test=0.821) total time=   0.0s
# [CV 9/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.838, test=0.744) total time=   0.0s
# [CV 10/10] END gamma=200.0, learning_rate=0.08, max_depth=6, n_estimators=100, reg_alpha=0.1, reg_lambda=3.2;, score=(train=0.838, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.969, test=0.949) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.970, test=0.885) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.972, test=0.910) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.972, test=0.846) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.972, test=0.962) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.969, test=0.936) total time=   0.1s
# [CV 7/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.973, test=0.923) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.969, test=0.872) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.972, test=0.885) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.025, max_depth=9, n_estimators=130, reg_alpha=1.6, reg_lambda=25.6;, score=(train=0.970, test=0.885) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.996, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.996, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.999, test=0.923) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.994, test=0.885) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.994, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.996, test=0.949) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.996, test=0.936) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.996, test=0.910) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.994, test=0.936) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.0, reg_lambda=6.4;, score=(train=0.997, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.862, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.868, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.868, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.865, test=0.769) total time=   0.0s
# [CV 5/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.869, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.848, test=0.821) total time=   0.0s
# [CV 7/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.862, test=0.885) total time=   0.0s
# [CV 8/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.871, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.853, test=0.821) total time=   0.0s
# [CV 10/10] END gamma=25.6, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=0.0, reg_lambda=102.4;, score=(train=0.866, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.994, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.994, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.994, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.993, test=0.897) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.994, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.993, test=0.949) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.990, test=0.936) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.993, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.991, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.08, max_depth=6, n_estimators=150, reg_alpha=1.6, reg_lambda=0.2;, score=(train=0.993, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.915, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.903, test=0.910) total time=   0.0s
# [CV 3/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.915, test=0.859) total time=   0.0s
# [CV 4/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.912, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.910, test=0.923) total time=   0.0s
# [CV 6/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.903, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.910, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.922, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.908, test=0.846) total time=   0.0s
# [CV 10/10] END gamma=25.6, learning_rate=0.04, max_depth=2, n_estimators=100, reg_alpha=1.6, reg_lambda=0.4;, score=(train=0.912, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.937) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.910) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.846) total time=   0.0s
# [CV 5/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.974) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.910) total time=   0.0s
# [CV 9/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.949) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=1.000, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.996, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.999, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=1.000, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.996, test=0.846) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.996, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.994, test=0.962) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.994, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.996, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.997, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.03, max_depth=5, n_estimators=115, reg_alpha=0.0, reg_lambda=0.8;, score=(train=0.997, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.885) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.962) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.910) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.05, max_depth=6, n_estimators=115, reg_alpha=0.1, reg_lambda=0.2;, score=(train=1.000, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.907, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.915, test=0.859) total time=   0.0s
# [CV 3/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.923, test=0.859) total time=   0.0s
# [CV 4/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.909, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.910, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.902, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.906, test=0.885) total time=   0.0s
# [CV 8/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.919, test=0.833) total time=   0.0s
# [CV 9/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.912, test=0.859) total time=   0.0s
# [CV 10/10] END gamma=12.8, learning_rate=0.01, max_depth=10, n_estimators=65, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.908, test=0.833) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.996, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.996, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.996, test=0.949) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.993, test=0.897) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.994, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.994, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.994, test=0.936) total time=   0.0s
# [CV 8/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.994, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.991, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.05, max_depth=8, n_estimators=130, reg_alpha=3.2, reg_lambda=0.2;, score=(train=0.994, test=0.910) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.830, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.848, test=0.833) total time=   0.0s
# [CV 3/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.835, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.844, test=0.756) total time=   0.0s
# [CV 5/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.842, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 7/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.845, test=0.846) total time=   0.0s
# [CV 8/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.849, test=0.821) total time=   0.0s
# [CV 9/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=102.4, learning_rate=0.08, max_depth=8, n_estimators=100, reg_alpha=0.4, reg_lambda=6.4;, score=(train=0.838, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.987, test=0.975) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.987, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.982, test=0.923) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.989, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.987, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.986, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.983, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.04, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=6.4;, score=(train=0.984, test=0.910) total time=   0.0s
# ...
# [CV 5/10] END gamma=51.2, learning_rate=0.06, max_depth=5, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=0.885, test=0.897) total time=   0.0s
# [CV 6/10] END gamma=51.2, learning_rate=0.06, max_depth=5, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=0.868, test=0.859) total time=   0.0s
# [CV 7/10] END gamma=51.2, learning_rate=0.06, max_depth=5, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=0.885, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=51.2, learning_rate=0.06, max_depth=5, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=0.883, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=51.2, learning_rate=0.06, max_depth=5, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=0.888, test=0.821) total time=   0.0s
# [CV 10/10] END gamma=51.2, learning_rate=0.06, max_depth=5, n_estimators=130, reg_alpha=0.2, reg_lambda=0.2;, score=(train=0.889, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.860, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.865, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.869, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.865, test=0.769) total time=   0.0s
# [CV 5/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.862, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.851, test=0.821) total time=   0.0s
# [CV 7/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.859, test=0.872) total time=   0.0s
# [CV 8/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.871, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.853, test=0.833) total time=   0.0s
# [CV 10/10] END gamma=51.2, learning_rate=0.03, max_depth=5, n_estimators=65, reg_alpha=0.1, reg_lambda=25.6;, score=(train=0.861, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.939, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.939, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.936, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.939, test=0.833) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.933, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.936, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.932, test=0.936) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.926, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.935, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=0.1, reg_lambda=200.0;, score=(train=0.936, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.846) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=0.999, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.910) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=1.000, test=0.923) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.0, reg_lambda=0.0;, score=(train=0.999, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.934, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.939, test=0.833) total time=   0.0s
# [CV 3/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.932, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.937, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.936, test=0.923) total time=   0.0s
# [CV 6/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.929, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.935, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.943, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.933, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.1, learning_rate=0.02, max_depth=6, n_estimators=80, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.935, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.979, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.970, test=0.910) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.979, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.977, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.970, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.969, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.974, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.976, test=0.936) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.977, test=0.923) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.7, max_depth=7, n_estimators=130, reg_alpha=6.4, reg_lambda=3.2;, score=(train=0.979, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.964, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.972, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.967, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.972, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.964, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.964, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.967, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.967, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.969, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.08, max_depth=5, n_estimators=130, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.969, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.477, test=0.481) total time=   0.0s
# [CV 2/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 3/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 4/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 5/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 6/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 7/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 8/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 9/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 10/10] END gamma=12.8, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=102.4, reg_lambda=0.8;, score=(train=0.478, test=0.474) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.932, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.932, test=0.923) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.939, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.930, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.930, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.926, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.933, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.935, test=0.910) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.929, test=0.846) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.02, max_depth=2, n_estimators=130, reg_alpha=1.6, reg_lambda=3.2;, score=(train=0.929, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.946, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.945, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.947, test=0.885) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.946, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.947, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.942, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.946, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.947, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.943, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.03, max_depth=7, n_estimators=130, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.947, test=0.872) total time=   0.0s
# CPU times: total: 19min 6s
# Wall time: 2min 23s

# %%
# Print out accuracy, F1 score, and roc auc score
for key, value in list(results_dict['xgbc_bcv'].items())[4:-1]:
    if key != 'classifier':
        print(f"{key}: {np.round(value,4)}")
# Out:
# train_accuracy: 0.9885
# val_accuracy: 0.931
# train F1-score label 1: 0.9889
# train F1-score label 0: 0.988
# val F1-score label 1: 0.9333
# val F1-score label 0: 0.9286
# val roc auc score: 0.9752

# %%
# Save the best model

model = clf.best_estimator_

pickle.dump(model, open('../trained_models/pss_model.pkl', 'wb'))

# %% [markdown]
# ### XGBoost Model Training with Scaled Data

# %%
# Initializing XGBoost Classifier with default parameters


xgbc = XGBClassifier(objective='binary:logistic',
                          booster='gbtree',
                          eval_metric='auc',
                          tree_method='hist',
                          grow_policy='lossguide')

# Training the XGBoost Classifier

xgbc.fit(X_train_scaled , y_train_scaled.values.ravel())

# Defining default parameters and the parameter grid for Bayesian search

default_params = {}
gparams = xgbc.get_params()

for key in gparams.keys():
    gp = gparams[key]
    default_params[key] = [gp]

# Deep copy the default parameters for potential modifications
params = deepcopy(default_params)

# Define the hyperparameter grid for hyperparameter tuning

param_grid = {'gamma': [2**i for i in range(-2, 8)],
              'learning_rate': [0.01,0.02, 0.025, 0.03, 0.04, 0.05, 0.06, 0.7,0.08],
              'max_depth': [2,5,6,7,8,9,10],
              'n_estimators': [50,65,80,100,115,130,150],
              'reg_alpha': [2**i for i in range(-2, 8)],
              'reg_lambda': [2**i for i in range(-2, 8)]}

# %%
# %%time

#start time
t0 = time.time()

#No. of jobs
bcvj = int(np.cumsum([len(x) for x in param_grid.values()])[-1])


# Initializing XGBoost Classifier with default parameters before Bayesian search
default_params_xgb = {}

for key in default_params.keys():
    default_params_xgb[key] = default_params[key][0]

#providing default parameters to xgbc model, before bayesian search cross-validation
xgbc = XGBClassifier(**default_params_xgb)

np.int = int
# Initializing Bayesian SearchCV with XGBoost Classifier
clf_scaled = BayesSearchCV(estimator=xgbc, search_spaces=param_grid, n_iter=bcvj, scoring='accuracy', cv=10, return_train_score=True, verbose=3)
clf_scaled.fit(X_train_scaled, y_train_scaled.values.ravel())

# Storing results in a DataFrame
df = pd.DataFrame(clf_scaled.cv_results_)
    
# Generating predictions for train and validation sets
train_predictions = clf_scaled.predict(X_train_scaled)
val_predictions = clf_scaled.predict(X_val_scaled)
    
# Calculating confusion matrices
cfm_train = confusion_matrix(y_train_scaled, train_predictions)
cfm_val = confusion_matrix(y_val_scaled, val_predictions)
    
# Calculating accuracy scores
accs_train = accuracy_score(y_train_scaled, train_predictions)
accs_val = accuracy_score(y_val_scaled, val_predictions)

    
# Calculating F1 scores
f1s_train_p1 = f1_score(y_train_scaled, train_predictions, pos_label=1)
f1s_train_p0 = f1_score(y_train_scaled, train_predictions, pos_label=0)
f1s_val_p1 = f1_score(y_val_scaled, val_predictions, pos_label=1)
f1s_val_p0 = f1_score(y_val_scaled, val_predictions, pos_label=0)

    
# Calculating Area Under the Receiver Operating Characteristic Curve
val_ras = roc_auc_score(y_val_scaled, clf_scaled.predict_proba(X_val)[:,1])
    
#best parameters
bp = clf_scaled.best_params_
results_dict = {}
    
# Storing computed values in a results dictionary
results_dict['xgbc_bcv'] = {'classifier': deepcopy(clf_scaled),
                            'cv_results': df.copy(),
                            'cfm_train': cfm_train,
                            'cfm_test': cfm_val,
                            'train_accuracy': accs_train,
                            'val_accuracy': accs_val,
                            'train F1-score label 1': f1s_train_p1,
                            'train F1-score label 0': f1s_train_p0,
                            'val F1-score label 1': f1s_val_p1,
                            'val F1-score label 0': f1s_val_p0,
                            'val roc auc score': val_ras,
                            'best_params': bp}

#stop time
t1 = time.time()

# Calculating elapsed time
bcvt = t1 - t0
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.903, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.899, test=0.859) total time=   0.0s
# [CV 3/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.915, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.912, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.906, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.898, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.903, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.906, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.908, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=16.0, learning_rate=0.05, max_depth=7, n_estimators=65, reg_alpha=8.0, reg_lambda=4.0;, score=(train=0.905, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.822, test=0.911) total time=   0.0s
# [CV 2/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.835, test=0.795) total time=   0.0s
# [CV 3/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.835, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.844, test=0.756) total time=   0.0s
# [CV 5/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.828, test=0.897) total time=   0.0s
# [CV 6/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 7/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.832, test=0.821) total time=   0.0s
# [CV 8/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.836, test=0.821) total time=   0.0s
# [CV 9/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=16.0, learning_rate=0.08, max_depth=5, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.838, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.944, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.943, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.949, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.945, test=0.833) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.946, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.942, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.940, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.946, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.940, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.05, max_depth=6, n_estimators=65, reg_alpha=0.25, reg_lambda=64.0;, score=(train=0.946, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.930, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.932, test=0.923) total time=   0.0s
# [CV 3/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.942, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.930, test=0.833) total time=   0.0s
# [CV 5/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.925, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.925, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.927, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.923, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.927, test=0.846) total time=   0.0s
# [CV 10/10] END gamma=16.0, learning_rate=0.08, max_depth=7, n_estimators=65, reg_alpha=1.0, reg_lambda=1.0;, score=(train=0.933, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.846, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.863, test=0.795) total time=   0.0s
# [CV 3/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.858, test=0.821) total time=   0.0s
# [CV 4/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.856, test=0.769) total time=   0.0s
# [CV 5/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.858, test=0.897) total time=   0.0s
# [CV 6/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.858, test=0.833) total time=   0.0s
# [CV 7/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.851, test=0.833) total time=   0.0s
# [CV 8/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.865, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.858, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=16.0, learning_rate=0.01, max_depth=2, n_estimators=50, reg_alpha=8.0, reg_lambda=0.5;, score=(train=0.852, test=0.821) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.887, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.899, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.898, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.896, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.889, test=0.923) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.879, test=0.872) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.896, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.906, test=0.833) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.895, test=0.821) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.025, max_depth=7, n_estimators=80, reg_alpha=64.0, reg_lambda=2.0;, score=(train=0.898, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.866, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.881, test=0.833) total time=   0.0s
# [CV 3/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.875, test=0.821) total time=   0.0s
# [CV 4/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.873, test=0.782) total time=   0.0s
# [CV 5/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.866, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.856, test=0.833) total time=   0.0s
# [CV 7/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.868, test=0.872) total time=   0.0s
# [CV 8/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.879, test=0.833) total time=   0.0s
# [CV 9/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.876, test=0.769) total time=   0.0s
# [CV 10/10] END gamma=4.0, learning_rate=0.025, max_depth=5, n_estimators=65, reg_alpha=4.0, reg_lambda=128.0;, score=(train=0.876, test=0.821) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.890, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.893, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.890, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.892, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.885, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.866, test=0.821) total time=   0.0s
# [CV 7/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.895, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.892, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.882, test=0.833) total time=   0.0s
# [CV 10/10] END gamma=4.0, learning_rate=0.04, max_depth=9, n_estimators=65, reg_alpha=32.0, reg_lambda=32.0;, score=(train=0.889, test=0.846) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.980, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.984, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.979, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.982, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.980, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.977, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.980, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.977, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.983, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.984, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.913, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.915, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.915, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.923, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.919, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.905, test=0.859) total time=   0.0s
# [CV 7/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.916, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.915, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.909, test=0.821) total time=   0.0s
# [CV 10/10] END gamma=4.0, learning_rate=0.025, max_depth=8, n_estimators=65, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.908, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.822, test=0.911) total time=   0.0s
# [CV 2/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.835, test=0.795) total time=   0.0s
# [CV 3/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.835, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.844, test=0.756) total time=   0.0s
# [CV 5/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.826, test=0.872) total time=   0.0s
# [CV 6/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 7/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.832, test=0.821) total time=   0.0s
# [CV 8/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.835, test=0.795) total time=   0.0s
# [CV 9/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=64.0, learning_rate=0.04, max_depth=6, n_estimators=100, reg_alpha=32.0, reg_lambda=2.0;, score=(train=0.838, test=0.808) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.962, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.962, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.957, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.962, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.959, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.963, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.970, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.963, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.967, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=80, reg_alpha=8.0, reg_lambda=2.0;, score=(train=0.966, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.981, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.980, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.977, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.979, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.973, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.977, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.980, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.976, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.980, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=0.5, reg_lambda=8.0;, score=(train=0.977, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.880, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.886, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.890, test=0.859) total time=   0.0s
# [CV 4/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.893, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.888, test=0.897) total time=   0.0s
# [CV 6/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.879, test=0.885) total time=   0.0s
# [CV 7/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.895, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.896, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.890, test=0.833) total time=   0.0s
# [CV 10/10] END gamma=32.0, learning_rate=0.08, max_depth=7, n_estimators=130, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.902, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.943, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.943, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.950, test=0.821) total time=   0.0s
# [CV 4/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.950, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.939, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.943, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.945, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.936, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.942, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=8.0, learning_rate=0.02, max_depth=9, n_estimators=115, reg_alpha=0.5, reg_lambda=2.0;, score=(train=0.946, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.936, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.936, test=0.910) total time=   0.0s
# [CV 3/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.943, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.936, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.935, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.932, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.935, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.933, test=0.910) total time=   0.0s
# [CV 9/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.935, test=0.859) total time=   0.0s
# [CV 10/10] END gamma=8.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.936, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.949, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.956, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.954, test=0.859) total time=   0.0s
# [CV 4/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.949, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.946, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.945, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.953, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.953, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.952, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=4.0, learning_rate=0.03, max_depth=6, n_estimators=100, reg_alpha=2.0, reg_lambda=8.0;, score=(train=0.953, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.895, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.892, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.903, test=0.859) total time=   0.0s
# [CV 4/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.900, test=0.795) total time=   0.0s
# [CV 5/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.896, test=0.897) total time=   0.0s
# [CV 6/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.893, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.895, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.890, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.898, test=0.846) total time=   0.0s
# [CV 10/10] END gamma=16.0, learning_rate=0.06, max_depth=5, n_estimators=80, reg_alpha=8.0, reg_lambda=16.0;, score=(train=0.895, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.972, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.973, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.966, test=0.885) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.972, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.966, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.969, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.972, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.962, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.973, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.025, max_depth=9, n_estimators=80, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.974, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.858, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.861, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.871, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.865, test=0.769) total time=   0.0s
# [CV 5/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.855, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.851, test=0.821) total time=   0.0s
# [CV 7/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.862, test=0.859) total time=   0.0s
# [CV 8/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.871, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.856, test=0.833) total time=   0.0s
# [CV 10/10] END gamma=64.0, learning_rate=0.03, max_depth=5, n_estimators=100, reg_alpha=4.0, reg_lambda=1.0;, score=(train=0.859, test=0.833) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.989, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.991, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.989, test=0.923) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.990, test=0.885) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.990, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.987, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.989, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.991, test=0.910) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.990, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.05, max_depth=9, n_estimators=80, reg_alpha=1.0, reg_lambda=4.0;, score=(train=0.990, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.909, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.910, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.916, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.913, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.913, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.902, test=0.859) total time=   0.0s
# [CV 7/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.906, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.913, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.909, test=0.859) total time=   0.0s
# [CV 10/10] END gamma=8.0, learning_rate=0.05, max_depth=9, n_estimators=50, reg_alpha=16.0, reg_lambda=2.0;, score=(train=0.912, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.977, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.976, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.976, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.976, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.970, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.974, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.977, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.969, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.976, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.02, max_depth=9, n_estimators=130, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.977, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.890, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.898, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.898, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.896, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.890, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.879, test=0.872) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.896, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.906, test=0.833) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.895, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.06, max_depth=9, n_estimators=80, reg_alpha=64.0, reg_lambda=4.0;, score=(train=0.898, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.986, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.984, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.979, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.984, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.984, test=0.949) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.983, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.982, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.980, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.982, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=2.0, reg_lambda=4.0;, score=(train=0.984, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.981, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.983, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.986, test=0.923) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.984, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.982, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.986, test=0.949) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.987, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.987, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.987, test=0.910) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=4.0, reg_lambda=4.0;, score=(train=0.984, test=0.897) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.966, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.972, test=0.859) total time=   0.0s
# [CV 3/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.967, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.969, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.962, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.966, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.969, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.973, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.970, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=0.5, learning_rate=0.01, max_depth=9, n_estimators=65, reg_alpha=0.5, reg_lambda=4.0;, score=(train=0.969, test=0.846) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.977, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.980, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.973, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.977, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.974, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.972, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.980, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.970, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.977, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.03, max_depth=9, n_estimators=100, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.977, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.963, test=0.937) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.969, test=0.910) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.964, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.967, test=0.859) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.962, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.966, test=0.936) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.969, test=0.936) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.966, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.967, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.03, max_depth=10, n_estimators=130, reg_alpha=8.0, reg_lambda=8.0;, score=(train=0.970, test=0.897) total time=   0.0s
# ...
# [CV 6/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=64.0, reg_lambda=0.5;, score=(train=0.873, test=0.872) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=64.0, reg_lambda=0.5;, score=(train=0.890, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=64.0, reg_lambda=0.5;, score=(train=0.900, test=0.833) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=64.0, reg_lambda=0.5;, score=(train=0.896, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=64.0, reg_lambda=0.5;, score=(train=0.898, test=0.846) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.890, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.892, test=0.859) total time=   0.0s
# [CV 3/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.905, test=0.859) total time=   0.0s
# [CV 4/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.895, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.896, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.892, test=0.897) total time=   0.0s
# [CV 7/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.899, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.895, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.893, test=0.821) total time=   0.0s
# [CV 10/10] END gamma=32.0, learning_rate=0.04, max_depth=8, n_estimators=130, reg_alpha=2.0, reg_lambda=2.0;, score=(train=0.902, test=0.859) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.855, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.855, test=0.833) total time=   0.0s
# [CV 3/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.845, test=0.821) total time=   0.0s
# [CV 4/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.865, test=0.769) total time=   0.0s
# [CV 5/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.853, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.839, test=0.795) total time=   0.0s
# [CV 7/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.845, test=0.846) total time=   0.0s
# [CV 8/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.863, test=0.833) total time=   0.0s
# [CV 9/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.844, test=0.795) total time=   0.0s
# [CV 10/10] END gamma=64.0, learning_rate=0.05, max_depth=10, n_estimators=80, reg_alpha=2.0, reg_lambda=16.0;, score=(train=0.852, test=0.795) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.964, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.963, test=0.885) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.963, test=0.910) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.963, test=0.846) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.964, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.964, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.969, test=0.897) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.963, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.964, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=4.0, reg_lambda=8.0;, score=(train=0.972, test=0.885) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.944, test=0.949) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.949, test=0.872) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.953, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.946, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.949, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.947, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.947, test=0.923) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.953, test=0.885) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.949, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.02, max_depth=10, n_estimators=130, reg_alpha=1.0, reg_lambda=32.0;, score=(train=0.954, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.477, test=0.481) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.477, test=0.487) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.05, max_depth=10, n_estimators=130, reg_alpha=128.0, reg_lambda=64.0;, score=(train=0.478, test=0.474) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.979, test=0.975) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.980, test=0.897) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.979, test=0.897) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.980, test=0.872) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.982, test=0.962) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.979, test=0.949) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.984, test=0.949) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.977, test=0.897) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.979, test=0.897) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.05, max_depth=5, n_estimators=130, reg_alpha=0.5, reg_lambda=16.0;, score=(train=0.980, test=0.910) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.922, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.919, test=0.910) total time=   0.0s
# [CV 3/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.927, test=0.872) total time=   0.0s
# [CV 4/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.927, test=0.821) total time=   0.0s
# [CV 5/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.923, test=0.936) total time=   0.0s
# [CV 6/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.917, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.920, test=0.910) total time=   0.0s
# [CV 8/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.925, test=0.859) total time=   0.0s
# [CV 9/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.915, test=0.872) total time=   0.0s
# [CV 10/10] END gamma=8.0, learning_rate=0.025, max_depth=6, n_estimators=130, reg_alpha=0.5, reg_lambda=32.0;, score=(train=0.923, test=0.872) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.860, test=0.924) total time=   0.0s
# [CV 2/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.862, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.863, test=0.846) total time=   0.0s
# [CV 4/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.865, test=0.769) total time=   0.0s
# [CV 5/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.863, test=0.885) total time=   0.0s
# [CV 6/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.848, test=0.821) total time=   0.0s
# [CV 7/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.863, test=0.885) total time=   0.0s
# [CV 8/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.872, test=0.846) total time=   0.0s
# [CV 9/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.861, test=0.808) total time=   0.0s
# [CV 10/10] END gamma=32.0, learning_rate=0.05, max_depth=7, n_estimators=130, reg_alpha=8.0, reg_lambda=32.0;, score=(train=0.863, test=0.833) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.954, test=0.962) total time=   0.0s
# [CV 2/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.956, test=0.846) total time=   0.0s
# [CV 3/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.954, test=0.833) total time=   0.0s
# [CV 4/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.950, test=0.808) total time=   0.0s
# [CV 5/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.952, test=0.910) total time=   0.0s
# [CV 6/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.959, test=0.923) total time=   0.0s
# [CV 7/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.956, test=0.885) total time=   0.0s
# [CV 8/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.956, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.949, test=0.885) total time=   0.0s
# [CV 10/10] END gamma=1.0, learning_rate=0.01, max_depth=10, n_estimators=80, reg_alpha=1.0, reg_lambda=8.0;, score=(train=0.957, test=0.846) total time=   0.0s
# CPU times: total: 11min
# Wall time: 1min 32s

# %%
# Print out accuracy, F1 score, and roc auc score
for key, value in list(results_dict['xgbc_bcv'].items())[4:-1]:
    if key != 'classifier':
        print(f"{key}: {np.round(value,4)}")
# Out:
# train_accuracy: 0.991
# val_accuracy: 0.908
# train F1-score label 1: 0.9914
# train F1-score label 0: 0.9907
# val F1-score label 1: 0.9091
# val F1-score label 0: 0.907
# val roc auc score: 0.9709

# %%
# Save the best model

model = clf_scaled.best_estimator_

pickle.dump(model, open('../trained_models/pss_model_scaled.pkl', 'wb'))

# %% [markdown]
# ## PSS SubCat MLM

# %%
# Load the processed training dataset

train = pd.read_csv( "../data/processed/subcat_train.csv",  index_col=0)

# Split the dataset into features (X) and target variable (y)

y_train = train['Shunt_type']
X_train = train.drop(['Shunt_type'], axis=1)


# define KNN imputer
imputer = KNNImputer()
# fit on the X_train
imputer.fit(X_train)
# transform the X_train
X_train = imputer.transform(X_train)


# Split the data into training and validation sets

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.10, shuffle=True, random_state= 123)

# Apply Synthetic Minority Over-sampling Technique (SMOTE) to balance the training dataset
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
# Initializing XGBoost Classifier with default parameters

xgbc = XGBClassifier(objective='multi:softmax',
                          booster='gbtree',
                          num_class=4,
                          eval_metric='mlogloss',
                          tree_method='hist',
                          grow_policy='lossguide'
                          )

# Training the XGBoost Classifier

xgbc.fit(X_train , y_train.values.ravel())

# Defining default parameters and the parameter grid for Bayesian search

default_params = {}
gparams = xgbc.get_params()

for key in gparams.keys():
    gp = gparams[key]
    default_params[key] = [gp]

# Deep copy the default parameters for potential modifications

params = deepcopy(default_params)

# Define the hyperparameter grid for hyperparameter tuning

param_grid = {'gamma': [2**i for i in range(-2, 8)],
              'learning_rate': [0.01, 0.03, 0.06, 0.1, 0.15, 0.2, 0.25, 0.3, 0.4, 0.5, 0.6, 0.7],
              'max_depth': [2,5,6,7,8,9,10,11,12],
              'n_estimators': [50,65,80,100,115,130,150],
              'reg_alpha': [2**i for i in range(-2, 8)],
              'reg_lambda': [2**i for i in range(-2, 8)]}

# %%
# %%time

#start time
t0 = time.time()

#No. of jobs
bcvj = int(np.cumsum([len(x) for x in param_grid.values()])[-1])


# Initializing XGBoost Classifier with default parameters before Bayesian search
default_params_xgb = {}

for key in default_params.keys():
    default_params_xgb[key] = default_params[key][0]

#providing default parameters to xgbc model, before randomized search cross-validation
xgbc = XGBClassifier(**default_params_xgb)

# Initializing Bayesian SearchCV with XGBoost Classifier

clf = BayesSearchCV(estimator=xgbc, search_spaces=param_grid, n_iter=bcvj, scoring='f1_weighted', cv=10, return_train_score=True, verbose=3)
clf.fit(X_train, y_train.values.ravel())

# Storing results in a DataFrame
df = pd.DataFrame(clf.cv_results_)
    
# Generating predictions for train and validation sets
train_predictions = clf.predict(X_train)
val_predictions = clf.predict(X_val)
    
# Calculating confusion matrices
cfm_train = confusion_matrix(y_train, train_predictions)
cfm_val = confusion_matrix(y_val, val_predictions)
    
# Calculating accuracy scores
accs_train = accuracy_score(y_train, train_predictions)
accs_val = accuracy_score(y_val, val_predictions)

    
# Calculating F1 scores
f1_train = f1_score(y_train, train_predictions, average='weighted')
f1_val = f1_score(y_val, val_predictions, average='weighted')

    
# Calculating Area Under the Receiver Operating Characteristic Curve
val_ras = roc_auc_score(y_val, clf.predict_proba(X_val), multi_class='ovo')
    
#best parameters
bp = clf.best_params_
results_dict = {}
    
# Storing computed values in a results dictionary
results_dict['xgbc_bcv'] = {'classifier': deepcopy(clf),
                            'cv_results': df.copy(),
                            'cfm_train': cfm_train,
                            'cfm_test': cfm_val,
                            'train_accuracy': accs_train,
                            'val_accuracy': accs_val,
                            'train F1-score': f1_train,
                            'val F1-score': f1_val,
                            'val roc auc score': val_ras,
                            'best_params': bp}

#stop time
t1 = time.time()

# Calculating elapsed time
bcvt = t1 - t0
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.866, test=0.750) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.845, test=0.771) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.842, test=0.765) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.846, test=0.809) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.820, test=0.833) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.815, test=0.777) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.839, test=0.786) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.827, test=0.860) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.817, test=0.768) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.815, test=0.795) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.995, test=0.867) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.882) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.995, test=0.889) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.903) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.955) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.944) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.996, test=0.949) total time=   0.0s
# [CV 8/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.933) total time=   0.0s
# [CV 9/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.949) total time=   0.0s
# [CV 10/10] END gamma=0.8, learning_rate=0.4, max_depth=11, n_estimators=65, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.994, test=0.956) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.949, test=0.821) total time=   0.1s
# [CV 2/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.945, test=0.846) total time=   0.1s
# [CV 3/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.939, test=0.872) total time=   0.1s
# [CV 4/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.937, test=0.909) total time=   0.1s
# [CV 5/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.943, test=0.938) total time=   0.1s
# [CV 6/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.942, test=0.893) total time=   0.1s
# [CV 7/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.939, test=0.921) total time=   0.1s
# [CV 8/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.942, test=0.916) total time=   0.1s
# [CV 9/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.933, test=0.880) total time=   0.1s
# [CV 10/10] END gamma=0.8, learning_rate=0.25, max_depth=11, n_estimators=100, reg_alpha=12.8, reg_lambda=102.4;, score=(train=0.937, test=0.910) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.974, test=0.839) total time=   0.0s
# [CV 2/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.967, test=0.853) total time=   0.0s
# [CV 3/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.966, test=0.855) total time=   0.0s
# [CV 4/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.966, test=0.892) total time=   0.0s
# [CV 5/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.965, test=0.939) total time=   0.0s
# [CV 6/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.968, test=0.910) total time=   0.0s
# [CV 7/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.963, test=0.950) total time=   0.0s
# [CV 8/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.964, test=0.904) total time=   0.0s
# [CV 9/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.970, test=0.909) total time=   0.0s
# [CV 10/10] END gamma=3.2, learning_rate=0.5, max_depth=8, n_estimators=80, reg_alpha=1.6, reg_lambda=0.8;, score=(train=0.961, test=0.916) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.448, test=0.381) total time=   0.0s
# [CV 2/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.339, test=0.317) total time=   0.0s
# [CV 3/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.353, test=0.338) total time=   0.0s
# [CV 4/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.349, test=0.372) total time=   0.0s
# [CV 5/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.354, test=0.357) total time=   0.0s
# [CV 6/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.358, test=0.343) total time=   0.0s
# [CV 7/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.357, test=0.340) total time=   0.0s
# [CV 8/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.343, test=0.325) total time=   0.0s
# [CV 9/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.355, test=0.365) total time=   0.0s
# [CV 10/10] END gamma=102.4, learning_rate=0.2, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.8;, score=(train=0.357, test=0.394) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.877, test=0.799) total time=   0.1s
# [CV 2/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.879, test=0.808) total time=   0.1s
# [CV 3/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.871, test=0.811) total time=   0.1s
# [CV 4/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.865, test=0.858) total time=   0.1s
# [CV 5/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.878, test=0.859) total time=   0.1s
# [CV 6/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.870, test=0.860) total time=   0.1s
# [CV 7/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.868, test=0.846) total time=   0.0s
# [CV 8/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.867, test=0.861) total time=   0.1s
# [CV 9/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.873, test=0.829) total time=   0.1s
# [CV 10/10] END gamma=6.4, learning_rate=0.1, max_depth=10, n_estimators=115, reg_alpha=25.6, reg_lambda=0.2;, score=(train=0.868, test=0.853) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.978, test=0.839) total time=   0.4s
# [CV 2/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.977, test=0.848) total time=   0.4s
# [CV 3/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.978, test=0.888) total time=   0.4s
# [CV 4/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.974, test=0.915) total time=   0.4s
# [CV 5/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.975, test=0.928) total time=   0.4s
# [CV 6/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.978, test=0.926) total time=   0.4s
# [CV 7/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.980, test=0.910) total time=   0.4s
# [CV 8/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.979, test=0.916) total time=   0.4s
# [CV 9/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.974, test=0.932) total time=   0.4s
# [CV 10/10] END gamma=1.6, learning_rate=0.03, max_depth=9, n_estimators=80, reg_alpha=1.6, reg_lambda=1.6;, score=(train=0.967, test=0.927) total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.872, test=0.799) total time=   0.0s
# [CV 2/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.865, test=0.809) total time=   0.0s
# [CV 3/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.869, test=0.817) total time=   0.0s
# [CV 4/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.865, test=0.870) total time=   0.0s
# [CV 5/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.856, test=0.871) total time=   0.0s
# [CV 6/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.869, test=0.854) total time=   0.0s
# [CV 7/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.865, test=0.852) total time=   0.0s
# [CV 8/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.867, test=0.872) total time=   0.0s
# [CV 9/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.869, test=0.834) total time=   0.0s
# [CV 10/10] END gamma=12.8, learning_rate=0.1, max_depth=5, n_estimators=80, reg_alpha=0.8, reg_lambda=51.2;, score=(train=0.867, test=0.864) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.943, test=0.810) total time=   0.1s
# [CV 2/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.937, test=0.846) total time=   0.1s
# [CV 3/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.935, test=0.860) total time=   0.1s
# [CV 4/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.933, test=0.899) total time=   0.1s
# [CV 5/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.937, test=0.927) total time=   0.1s
# [CV 6/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.934, test=0.894) total time=   0.1s
# [CV 7/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.938, test=0.893) total time=   0.1s
# [CV 8/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.938, test=0.916) total time=   0.1s
# [CV 9/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.925, test=0.880) total time=   0.1s
# [CV 10/10] END gamma=0.8, learning_rate=0.15, max_depth=11, n_estimators=115, reg_alpha=25.6, reg_lambda=25.6;, score=(train=0.932, test=0.905) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.971, test=0.856) total time=   0.5s
# [CV 2/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.973, test=0.858) total time=   0.5s
# [CV 3/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.973, test=0.871) total time=   0.5s
# [CV 4/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.974, test=0.914) total time=   0.7s
# [CV 5/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.966, test=0.915) total time=   0.5s
# [CV 6/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.976, test=0.921) total time=   0.6s
# [CV 7/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.974, test=0.887) total time=   0.5s
# [CV 8/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.970, test=0.911) total time=   0.5s
# [CV 9/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.973, test=0.908) total time=   0.5s
# [CV 10/10] END gamma=0.8, learning_rate=0.01, max_depth=5, n_estimators=130, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.969, test=0.931) total time=   0.5s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.986, test=0.828) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.983, test=0.876) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.981, test=0.899) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.980, test=0.921) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.980, test=0.921) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.981, test=0.927) total time=   0.1s
# [CV 7/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.977, test=0.932) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.980, test=0.933) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.979, test=0.932) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=80, reg_alpha=12.8, reg_lambda=0.0;, score=(train=0.975, test=0.910) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.864, test=0.739) total time=   0.0s
# [CV 2/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.859, test=0.777) total time=   0.0s
# [CV 3/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.853, test=0.775) total time=   0.0s
# [CV 4/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.851, test=0.825) total time=   0.0s
# [CV 5/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.847, test=0.849) total time=   0.0s
# [CV 6/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.859, test=0.860) total time=   0.0s
# [CV 7/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.855, test=0.834) total time=   0.0s
# [CV 8/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.845, test=0.810) total time=   0.0s
# [CV 9/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.854, test=0.823) total time=   0.0s
# [CV 10/10] END gamma=25.6, learning_rate=0.6, max_depth=9, n_estimators=80, reg_alpha=0.1, reg_lambda=0.8;, score=(train=0.863, test=0.836) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.850, test=0.749) total time=   0.0s
# [CV 2/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.828, test=0.743) total time=   0.0s
# [CV 3/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.829, test=0.771) total time=   0.0s
# [CV 4/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.812, test=0.777) total time=   0.0s
# [CV 5/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.822, test=0.821) total time=   0.0s
# [CV 6/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.817, test=0.779) total time=   0.0s
# [CV 7/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.832, test=0.808) total time=   0.0s
# [CV 8/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.829, test=0.854) total time=   0.0s
# [CV 9/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.819, test=0.782) total time=   0.0s
# [CV 10/10] END gamma=0.2, learning_rate=0.1, max_depth=5, n_estimators=100, reg_alpha=102.4, reg_lambda=3.2;, score=(train=0.817, test=0.794) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.928, test=0.795) total time=   0.1s
# [CV 2/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.918, test=0.830) total time=   0.1s
# [CV 3/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.912, test=0.844) total time=   0.1s
# [CV 4/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.915, test=0.883) total time=   0.1s
# [CV 5/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.913, test=0.870) total time=   0.1s
# [CV 6/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.905, test=0.876) total time=   0.1s
# [CV 7/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.914, test=0.858) total time=   0.1s
# [CV 8/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.915, test=0.894) total time=   0.0s
# [CV 9/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.909, test=0.858) total time=   0.0s
# [CV 10/10] END gamma=0.4, learning_rate=0.25, max_depth=10, n_estimators=115, reg_alpha=51.2, reg_lambda=6.4;, score=(train=0.914, test=0.888) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.843, test=0.747) total time=   0.0s
# [CV 2/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.835, test=0.765) total time=   0.0s
# [CV 3/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.832, test=0.758) total time=   0.0s
# [CV 4/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.822, test=0.823) total time=   0.0s
# [CV 5/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.815, test=0.819) total time=   0.0s
# [CV 6/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.803, test=0.806) total time=   0.0s
# [CV 7/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.825, test=0.801) total time=   0.0s
# [CV 8/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.819, test=0.820) total time=   0.0s
# [CV 9/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.844, test=0.801) total time=   0.0s
# [CV 10/10] END gamma=51.2, learning_rate=0.25, max_depth=8, n_estimators=115, reg_alpha=0.2, reg_lambda=1.6;, score=(train=0.832, test=0.822) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.933, test=0.801) total time=   0.2s
# [CV 2/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.928, test=0.830) total time=   0.2s
# [CV 3/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.925, test=0.850) total time=   0.2s
# [CV 4/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.917, test=0.893) total time=   0.2s
# [CV 5/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.924, test=0.899) total time=   0.2s
# [CV 6/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.927, test=0.860) total time=   0.2s
# [CV 7/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.922, test=0.887) total time=   0.2s
# [CV 8/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.923, test=0.905) total time=   0.2s
# [CV 9/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.918, test=0.863) total time=   0.2s
# [CV 10/10] END gamma=1.6, learning_rate=0.06, max_depth=8, n_estimators=115, reg_alpha=25.6, reg_lambda=3.2;, score=(train=0.915, test=0.899) total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.884, test=0.773) total time=   0.1s
# [CV 2/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.862, test=0.787) total time=   0.1s
# [CV 3/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.873, test=0.777) total time=   0.1s
# [CV 4/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.853, test=0.815) total time=   0.1s
# [CV 5/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.855, test=0.822) total time=   0.1s
# [CV 6/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.867, test=0.827) total time=   0.1s
# [CV 7/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.872, test=0.837) total time=   0.1s
# [CV 8/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.871, test=0.889) total time=   0.1s
# [CV 9/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.866, test=0.818) total time=   0.1s
# [CV 10/10] END gamma=0.0, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=102.4, reg_lambda=1.6;, score=(train=0.853, test=0.808) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.956, test=0.828) total time=   0.1s
# [CV 2/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.957, test=0.841) total time=   0.1s
# [CV 3/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.945, test=0.871) total time=   0.1s
# [CV 4/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.945, test=0.887) total time=   0.1s
# [CV 5/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.951, test=0.905) total time=   0.1s
# [CV 6/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.943, test=0.905) total time=   0.1s
# [CV 7/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.955, test=0.904) total time=   0.1s
# [CV 8/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.955, test=0.915) total time=   0.1s
# [CV 9/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.951, test=0.887) total time=   0.1s
# [CV 10/10] END gamma=0.1, learning_rate=0.7, max_depth=11, n_estimators=150, reg_alpha=25.6, reg_lambda=0.4;, score=(train=0.946, test=0.899) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.218, test=0.206) total time=   0.0s
# [CV 2/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.216, test=0.231) total time=   0.0s
# [CV 3/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.218, test=0.204) total time=   0.0s
# [CV 4/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.217, test=0.217) total time=   0.0s
# [CV 5/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.216, test=0.227) total time=   0.0s
# [CV 6/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.226, test=0.199) total time=   0.0s
# [CV 7/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.225, test=0.211) total time=   0.0s
# [CV 8/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.224, test=0.223) total time=   0.0s
# [CV 9/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.223, test=0.221) total time=   0.0s
# [CV 10/10] END gamma=200.0, learning_rate=0.01, max_depth=8, n_estimators=65, reg_alpha=1.6, reg_lambda=51.2;, score=(train=0.215, test=0.224) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.861) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.898) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.933) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.931) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.949) total time=   0.1s
# [CV 7/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.944) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.932) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.955) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.4, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.978) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.227, test=0.227) total time=   0.0s
# [CV 2/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.343, test=0.291) total time=   0.0s
# [CV 3/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.218, test=0.204) total time=   0.0s
# [CV 4/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.217, test=0.217) total time=   0.0s
# [CV 5/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.216, test=0.227) total time=   0.0s
# [CV 6/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.233, test=0.225) total time=   0.0s
# [CV 7/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.227, test=0.222) total time=   0.0s
# [CV 8/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.232, test=0.227) total time=   0.0s
# [CV 9/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.227, test=0.223) total time=   0.0s
# [CV 10/10] END gamma=25.6, learning_rate=0.03, max_depth=9, n_estimators=65, reg_alpha=102.4, reg_lambda=0.1;, score=(train=0.215, test=0.224) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.878) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.915) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.933) total time=   0.2s
# [CV 4/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.943) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 6/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.960) total time=   0.2s
# [CV 7/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.943) total time=   0.2s
# [CV 8/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.938) total time=   0.2s
# [CV 9/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.966) total time=   0.2s
# [CV 10/10] END gamma=0.2, learning_rate=0.300000012, max_depth=11, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=1.000, test=0.977) total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.878) total time=   1.4s
# [CV 2/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.899) total time=   1.4s
# [CV 3/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.922) total time=   1.4s
# [CV 4/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.915) total time=   1.4s
# [CV 5/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.944) total time=   1.4s
# [CV 6/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.949) total time=   1.4s
# [CV 7/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.996, test=0.915) total time=   1.5s
# [CV 8/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.996, test=0.927) total time=   1.5s
# [CV 9/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.995, test=0.926) total time=   1.5s
# [CV 10/10] END gamma=0.2, learning_rate=0.01, max_depth=11, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.944) total time=   1.5s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.992, test=0.850) total time=   1.1s
# [CV 2/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.989, test=0.870) total time=   1.2s
# [CV 3/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.993, test=0.905) total time=   1.3s
# [CV 4/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.991, test=0.920) total time=   1.2s
# [CV 5/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.991, test=0.905) total time=   1.2s
# [CV 6/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.992, test=0.932) total time=   1.1s
# [CV 7/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.993, test=0.915) total time=   1.2s
# [CV 8/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.992, test=0.933) total time=   1.2s
# [CV 9/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.994, test=0.920) total time=   1.2s
# [CV 10/10] END gamma=0.1, learning_rate=0.01, max_depth=7, n_estimators=150, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.992, test=0.949) total time=   1.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.979, test=0.850) total time=   0.4s
# [CV 2/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.974, test=0.859) total time=   0.5s
# [CV 3/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.976, test=0.877) total time=   0.4s
# [CV 4/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.975, test=0.926) total time=   0.5s
# [CV 5/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.976, test=0.905) total time=   0.5s
# [CV 6/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.981, test=0.921) total time=   0.5s
# [CV 7/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.978, test=0.915) total time=   0.5s
# [CV 8/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.981, test=0.910) total time=   0.5s
# [CV 9/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.979, test=0.893) total time=   0.5s
# [CV 10/10] END gamma=0.4, learning_rate=0.01, max_depth=6, n_estimators=80, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.972, test=0.926) total time=   0.4s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.859, test=0.782) total time=   0.1s
# [CV 2/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.848, test=0.752) total time=   0.1s
# [CV 3/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.857, test=0.806) total time=   0.1s
# [CV 4/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.855, test=0.835) total time=   0.1s
# [CV 5/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.851, test=0.866) total time=   0.1s
# [CV 6/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.853, test=0.835) total time=   0.1s
# [CV 7/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.849, test=0.853) total time=   0.1s
# [CV 8/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.847, test=0.861) total time=   0.1s
# [CV 9/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.853, test=0.822) total time=   0.1s
# [CV 10/10] END gamma=25.6, learning_rate=0.01, max_depth=9, n_estimators=115, reg_alpha=0.8, reg_lambda=0.2;, score=(train=0.857, test=0.859) total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.829, test=0.748) total time=   0.0s
# [CV 2/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.831, test=0.789) total time=   0.0s
# [CV 3/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.837, test=0.757) total time=   0.0s
# [CV 4/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.812, test=0.812) total time=   0.0s
# [CV 5/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.811, test=0.847) total time=   0.0s
# [CV 6/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.827, test=0.812) total time=   0.0s
# [CV 7/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.820, test=0.812) total time=   0.0s
# [CV 8/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.812, test=0.797) total time=   0.0s
# [CV 9/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.832, test=0.776) total time=   0.0s
# [CV 10/10] END gamma=51.2, learning_rate=0.300000012, max_depth=7, n_estimators=80, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.819, test=0.784) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.855, test=0.786) total time=   0.0s
# [CV 2/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.856, test=0.812) total time=   0.0s
# [CV 3/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.849, test=0.788) total time=   0.0s
# [CV 4/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.850, test=0.854) total time=   0.0s
# [CV 5/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.838, test=0.857) total time=   0.0s
# [CV 6/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.840, test=0.848) total time=   0.0s
# [CV 7/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.845, test=0.829) total time=   0.0s
# [CV 8/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.850, test=0.848) total time=   0.0s
# [CV 9/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.864, test=0.834) total time=   0.0s
# [CV 10/10] END gamma=12.8, learning_rate=0.7, max_depth=9, n_estimators=65, reg_alpha=3.2, reg_lambda=102.4;, score=(train=0.847, test=0.847) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.908, test=0.810) total time=   0.0s
# [CV 2/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.912, test=0.811) total time=   0.0s
# [CV 3/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.902, test=0.837) total time=   0.0s
# [CV 4/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.896, test=0.852) total time=   0.0s
# [CV 5/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.890, test=0.840) total time=   0.0s
# [CV 6/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.883, test=0.893) total time=   0.0s
# [CV 7/10] END gamma=0.8, learning_rate=0.7, max_depth=12, n_estimators=80, reg_alpha=51.2, reg_lambda=3.2;, score=(train=0.892, test=0.828) total time=   0.0s
# ...
# [CV 7/10] END gamma=1.6, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=1.6, reg_lambda=0.1;, score=(train=0.986, test=0.921) total time=   0.1s
# [CV 8/10] END gamma=1.6, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=1.6, reg_lambda=0.1;, score=(train=0.988, test=0.927) total time=   0.1s
# [CV 9/10] END gamma=1.6, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=1.6, reg_lambda=0.1;, score=(train=0.988, test=0.938) total time=   0.1s
# [CV 10/10] END gamma=1.6, learning_rate=0.25, max_depth=11, n_estimators=130, reg_alpha=1.6, reg_lambda=0.1;, score=(train=0.984, test=0.955) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.889) total time=   0.2s
# [CV 2/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.904) total time=   0.2s
# [CV 3/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.928) total time=   0.2s
# [CV 4/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.944) total time=   0.2s
# [CV 5/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.961) total time=   0.2s
# [CV 6/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.972) total time=   0.2s
# [CV 7/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.955) total time=   0.2s
# [CV 8/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.961) total time=   0.2s
# [CV 9/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.960) total time=   0.2s
# [CV 10/10] END gamma=0.0, learning_rate=0.6, max_depth=11, n_estimators=115, reg_alpha=0.4, reg_lambda=6.4;, score=(train=1.000, test=0.978) total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.992, test=0.855) total time=   0.0s
# [CV 2/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.990, test=0.870) total time=   0.0s
# [CV 3/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.989, test=0.888) total time=   0.0s
# [CV 4/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.990, test=0.919) total time=   0.0s
# [CV 5/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.988, test=0.944) total time=   0.0s
# [CV 6/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.991, test=0.938) total time=   0.0s
# [CV 7/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.993, test=0.949) total time=   0.0s
# [CV 8/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.989, test=0.921) total time=   0.0s
# [CV 9/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.990, test=0.949) total time=   0.0s
# [CV 10/10] END gamma=1.6, learning_rate=0.4, max_depth=10, n_estimators=50, reg_alpha=0.8, reg_lambda=0.8;, score=(train=0.989, test=0.961) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.872) total time=   0.1s
# [CV 2/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.921) total time=   0.1s
# [CV 3/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.911) total time=   0.1s
# [CV 4/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.944) total time=   0.1s
# [CV 5/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.955) total time=   0.1s
# [CV 6/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 7/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.966) total time=   0.1s
# [CV 8/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 9/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.961) total time=   0.1s
# [CV 10/10] END gamma=0.1, learning_rate=0.6, max_depth=11, n_estimators=65, reg_alpha=0.1, reg_lambda=12.8;, score=(train=1.000, test=0.978) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.278, test=0.251) total time=   0.0s
# [CV 2/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.275, test=0.270) total time=   0.0s
# [CV 3/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.275, test=0.277) total time=   0.0s
# [CV 4/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.276, test=0.275) total time=   0.0s
# [CV 5/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.276, test=0.276) total time=   0.0s
# [CV 6/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.275, test=0.276) total time=   0.0s
# [CV 7/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.275, test=0.270) total time=   0.0s
# [CV 8/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.276, test=0.273) total time=   0.0s
# [CV 9/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.274, test=0.269) total time=   0.0s
# [CV 10/10] END gamma=0.0, learning_rate=0.300000012, max_depth=10, n_estimators=80, reg_alpha=200.0, reg_lambda=0.0;, score=(train=0.274, test=0.272) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.838) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.904) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.916) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.993, test=0.943) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.991, test=0.949) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.938) total time=   0.2s
# [CV 7/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.955) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.950) total time=   0.2s
# [CV 9/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.993, test=0.937) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.5, max_depth=8, n_estimators=115, reg_alpha=0.4, reg_lambda=102.4;, score=(train=0.994, test=0.950) total time=   0.2s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.800, test=0.718) total time=   0.0s
# [CV 2/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.814, test=0.742) total time=   0.0s
# [CV 3/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.796, test=0.705) total time=   0.0s
# [CV 4/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.778, test=0.731) total time=   0.0s
# [CV 5/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.786, test=0.828) total time=   0.0s
# [CV 6/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.786, test=0.784) total time=   0.0s
# [CV 7/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.792, test=0.802) total time=   0.0s
# [CV 8/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.795, test=0.779) total time=   0.0s
# [CV 9/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.810, test=0.800) total time=   0.0s
# [CV 10/10] END gamma=51.2, learning_rate=0.300000012, max_depth=8, n_estimators=65, reg_alpha=0.1, reg_lambda=51.2;, score=(train=0.791, test=0.796) total time=   0.0s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.855) total time=   0.1s
# [CV 2/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.893) total time=   0.1s
# [CV 3/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.894) total time=   0.1s
# [CV 4/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.938) total time=   0.1s
# [CV 5/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.961) total time=   0.1s
# [CV 6/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.966) total time=   0.1s
# [CV 7/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.949) total time=   0.1s
# [CV 8/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.944) total time=   0.1s
# [CV 9/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.961) total time=   0.1s
# [CV 10/10] END gamma=0.8, learning_rate=0.300000012, max_depth=11, n_estimators=115, reg_alpha=0.2, reg_lambda=0.8;, score=(train=0.999, test=0.966) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.850) total time=   0.1s
# [CV 2/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.933) total time=   0.1s
# [CV 3/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.939) total time=   0.1s
# [CV 4/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.960) total time=   0.1s
# [CV 5/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.978) total time=   0.1s
# [CV 6/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.966) total time=   0.1s
# [CV 7/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.949) total time=   0.1s
# [CV 8/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.960) total time=   0.1s
# [CV 9/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.972) total time=   0.1s
# [CV 10/10] END gamma=0.2, learning_rate=0.300000012, max_depth=2, n_estimators=115, reg_alpha=0.0, reg_lambda=0.2;, score=(train=1.000, test=0.983) total time=   0.1s
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 1/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.999, test=0.883) total time=   0.1s
# [CV 2/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.999, test=0.899) total time=   0.1s
# [CV 3/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.998, test=0.927) total time=   0.1s
# [CV 4/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.997, test=0.926) total time=   0.1s
# [CV 5/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.998, test=0.955) total time=   0.1s
# [CV 6/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.999, test=0.949) total time=   0.1s
# [CV 7/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.998, test=0.955) total time=   0.1s
# [CV 8/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.998, test=0.938) total time=   0.1s
# [CV 9/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.997, test=0.943) total time=   0.1s
# [CV 10/10] END gamma=0.8, learning_rate=0.300000012, max_depth=7, n_estimators=130, reg_alpha=0.4, reg_lambda=0.8;, score=(train=0.998, test=0.983) total time=   0.1s
# CPU times: total: 42min 57s
# Wall time: 4min 13s

# %%
# Print out accuracy, F1 score, and roc auc score
for key, value in list(results_dict['xgbc_bcv'].items())[4:-1]:
    if key != 'classifier':
        print(f"{key}: {np.round(value,4)}")
# Out:
# train_accuracy: 0.9994
# val_accuracy: 0.8391
# train F1-score: 0.9994
# val F1-score: 0.8274
# val roc auc score: 0.9396

# %%
# Save the best model

model = clf.best_estimator_

pickle.dump(model, open('../trained_models/subcat_model.pkl', 'wb'))
